# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# -10 to 10, with 100 points
x = np.linspace(-10, 10, 100)
y = np.sin(x)

plt.plot(x, y, marker="x")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
